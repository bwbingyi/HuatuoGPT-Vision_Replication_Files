# %%
# !uv pip install huggingface_hub
# !uv pip install datasets
# Out:
# Using Python 3.13.5 environment at: /Users/bingyiwang/VS/.venv
# Audited 1 package in 4ms
# Using Python 3.13.5 environment at: /Users/bingyiwang/VS/.venv
# Resolved 42 packages in 989ms
# ⠙ Preparing packages... (0/13)
# ⠙ Preparing packages... (0/13)------------------     0 B/7.31 KiB
# ⠙ Preparing packages... (0/13)--------- 7.31 KiB/7.31 KiB
# ⠙ Preparing packages... (0/13)/13)
# ⠙ Preparing packages... (0/13)------------------     0 B/14.91 KiB
# ⠙ Preparing packages... (0/13)--------- 14.87 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)--------- 14.87 KiB/14.91 KiB
# aiohappyeyeballs     ------------------------------ 14.87 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------     0 B/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.87 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.91 KiB/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.91 KiB/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.91 KiB/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.91 KiB/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.91 KiB/42.50 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# multidict            ------------------------------ 14.91 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------     0 B/83.84 KiB
# aiohappyeyeballs     ------------------------------ 14.91 KiB/14.91 KiB
# multidict            ------------------------------ 14.91 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# multidict            ------------------------------ 14.91 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# multidict            ------------------------------ 30.91 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# multidict            ------------------------------ 42.50 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# multidict            ------------------------------ 42.50 KiB/42.50 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# ⠙ Preparing packages... (0/13)------------------ 14.92 KiB/83.84 KiB
# xxhash               ------------------------------ 14.91 KiB/30.10 KiB
# propcache            ------------------------------ 14.91 KiB/45.22 KiB
# frozenlist           ------------------------------ 14.91 KiB/48.26 KiB
# yarl                 ------------------------------ 83.84 KiB/83.84 KiB
# dill                 ------------------------------ 14.88 KiB/116.86 KiB
# datasets             ------------------------------     0 B/508.46 KiB
# ⠙ Preparing packages... (0/13)------------------     0 B/9.40 MiB
# xxhash               ------------------------------ 14.91 KiB/30.10 KiB
# propcache            ------------------------------ 45.22 KiB/45.22 KiB
# frozenlist           ------------------------------ 14.91 KiB/48.26 KiB
# dill                 ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess         ------------------------------     0 B/148.36 KiB
# aiohttp              ------------------------------     0 B/479.20 KiB
# datasets             ------------------------------     0 B/508.46 KiB
# pandas               ------------------------------     0 B/9.40 MiB
# ⠙ Preparing packages... (0/13)------------------     0 B/32.63 MiB
# xxhash               ------------------------------ 14.91 KiB/30.10 KiB
# frozenlist           ------------------------------ 14.91 KiB/48.26 KiB
# dill                 ------------------------------ 14.88 KiB/116.86 KiB
# multiprocess         ------------------------------     0 B/148.36 KiB
# aiohttp              ------------------------------     0 B/479.20 KiB
# datasets             ------------------------------     0 B/508.46 KiB
# pandas               ------------------------------     0 B/9.40 MiB
# ⠙ Preparing packages... (0/13)------------------     0 B/32.63 MiB
# frozenlist           ------------------------------ 30.91 KiB/48.26 KiB
# dill                 ------------------------------ 30.88 KiB/116.86 KiB
# multiprocess         ------------------------------ 14.91 KiB/148.36 KiB
# aiohttp              ------------------------------ 14.91 KiB/479.20 KiB
# datasets             ------------------------------ 16.00 KiB/508.46 KiB
# pandas               ------------------------------ 16.00 KiB/9.40 MiB
# ⠙ Preparing packages... (0/13)------------------     0 B/32.63 MiB
# dill                 ------------------------------ 62.78 KiB/116.86 KiB
# multiprocess         ------------------------------ 30.91 KiB/148.36 KiB
# aiohttp              ------------------------------ 30.91 KiB/479.20 KiB
# datasets             ------------------------------ 48.00 KiB/508.46 KiB
# pandas               ------------------------------ 33.67 KiB/9.40 MiB
# ⠹ Preparing packages... (7/13)------------------
# ⠴ Preparing packages... (11/13)----------------- 7.67 MiB/32.63 MiB
# pandas               ------------------------------ 6.59 MiB/9.40 MiB
# ⠴ Preparing packages... (11/13)----------------- 9.06 MiB/32.63 MiB
# pandas               ------------------------------ 8.56 MiB/9.40 MiB
# ⠴ Preparing packages... (11/13)----------------- 9.16 MiB/32.63 MiB
# pandas               ------------------------------ 8.58 MiB/9.40 MiB
# ⠦ Preparing packages... (11/13)----------------- 10.51 MiB/32.63 MiB
# ⠦ Preparing packages... (11/13)----------------- 10.97 MiB/32.63 MiB
# ⠦ Preparing packages... (11/13)----------------- 12.22 MiB/32.63 MiB
# ⠦ Preparing packages... (11/13)----------------- 14.62 MiB/32.63 MiB
# ⠧ Preparing packages... (12/13)2m--------------- 16.37 MiB/32.63 MiB
# ⠧ Preparing packages... (12/13)-------------- 18.05 MiB/32.63 MiB
# ⠧ Preparing packages... (12/13)-------------- 18.08 MiB/32.63 MiB
# ⠧ Preparing packages... (12/13)-------------- 18.11 MiB/32.63 MiB
# ⠧ Preparing packages... (12/13)-------------- 18.12 MiB/32.63 MiB
# ⠇ Preparing packages... (12/13)------------- 18.71 MiB/32.63 MiB
# ⠇ Preparing packages... (12/13)0m----------- 21.03 MiB/32.63 MiB
# ⠇ Preparing packages... (12/13)--------- 22.94 MiB/32.63 MiB
# ⠇ Preparing packages... (12/13)-------- 25.01 MiB/32.63 MiB
# ⠋ Preparing packages... (12/13)-------- 27.14 MiB/32.63 MiB
# ⠋ Preparing packages... (12/13)-------- 29.42 MiB/32.63 MiB
# ⠋ Preparing packages... (12/13)-------- 31.03 MiB/32.63 MiB
# ⠋ Preparing packages... (12/13)-------- 31.35 MiB/32.63 MiB
# ⠙ Preparing packages... (12/13)-------- 31.37 MiB/32.63 MiB
# Prepared 13 packages in 1.89s
# Installed 13 packages in 34ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + datasets==4.6.1
#  + dill==0.4.0
#  + frozenlist==1.8.0
#  + multidict==6.7.1
#  + multiprocess==0.70.18
#  + pandas==3.0.1
#  + propcache==0.4.1
#  + pyarrow==23.0.1
#  + xxhash==3.6.0
#  + yarl==1.23.0

# %%
from huggingface_hub import login
from getpass import getpass
token = getpass("Enter your Hugging Face token: ")
login(token=token)

# %%
from datasets import load_dataset

ds = load_dataset("FreedomIntelligence/Medical_Multimodal_Evaluation_Data")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# medical_multimodel_evaluation_data.json:   0%|          | 0.00/5.98M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/17303 [00:00<?, ? examples/s]

# %%
import os
output_folder = "Medical_Multimodal_Evaluation_Data"
filename = "medical_multimodel_evaluation_data.json"

os.makedirs(output_folder, exist_ok=True)
ds['test'].to_json(f"{output_folder}/{filename}")
# Out:
# Creating json from Arrow format:   0%|          | 0/18 [00:00<?, ?ba/s]
# 4556294

# %%
import requests
import zipfile
import os
from io import BytesIO

url = "https://huggingface.co/datasets/FreedomIntelligence/Medical_Multimodal_Evaluation_Data/resolve/main/images.zip"

print("Downloading images...")
response = requests.get(url)
target_folder = "Medical_Multimodal_Evaluation_Data/images"

if response.status_code == 200:
    print("Download complete. Unzipping...")
    os.makedirs(target_folder, exist_ok=True)
    with zipfile.ZipFile(BytesIO(response.content)) as z:
        z.extractall(target_folder)
    print(f"Images successfully unzipped to: {target_folder}")
else:
    print(f"Failed to download. Status code: {response.status_code}")
    print("Please check the exact URL on the Hugging Face dataset page.")
# Out:
# Downloading images...
# Download complete. Unzipping...
# Images successfully unzipped to: Medical_Multimodal_Evaluation_Data/images
