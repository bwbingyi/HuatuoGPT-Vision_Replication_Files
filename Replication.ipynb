# %%
# !git clone https://github.com/FreedomIntelligence/HuatuoGPT-Vision
# Out:
# Cloning into 'HuatuoGPT-Vision'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 88 (delta 18), reused 9 (delta 9), pack-reused 65 (from 1)
# Receiving objects: 100% (88/88), 48.22 KiB | 1.34 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# %cd HuatuoGPT-Vision
# Out:
# /Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision Replication/HuatuoGPT-Vision

# %%
# !git add Replication.ipynb
# !git commit -m "first iteration"
# !git push origin main
