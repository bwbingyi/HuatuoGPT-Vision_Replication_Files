# %%
# %cd ../HuatuoGPT-Vision-Replication
# !uv pip install -r requirements.txt
# %cd ../My_Work
# Out:
# /Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision-Replication
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Resolved 66 packages in 321ms
# Uninstalled 1 package in 793ms
# Installed 1 package in 235ms
#  ~ torch==2.0.1
# /Users/bingyiwang/VS Code/AI Project/My_Work

# %%
# !uv pip install huggingface_hub
# !uv pip install datasets
# !uv pip install setuptools
# !uv pip uninstall bitsandbytes
# Out:
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Audited 1 package in 2ms
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Audited 1 package in 10ms
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Audited 1 package in 1ms
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Uninstalled 1 package in 10ms
#  - bitsandbytes==0.41.0

# %%
# !uv pip install --upgrade wandb
# Out:
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Resolved 20 packages in 661ms
# ⠙ Preparing packages... (0/6)
# ⠙ Preparing packages... (0/6)-------------------     0 B/14.27 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/14.27 KiB
# annotated-types      ------------------------------     0 B/13.32 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/14.27 KiB
# annotated-types      ------------------------------     0 B/13.32 KiB
# ⠙ Preparing packages... (0/6)---------- 14.27 KiB/14.27 KiB
# annotated-types      ------------------------------     0 B/13.32 KiB
# ⠙ Preparing packages... (0/6)---------- 14.27 KiB/14.27 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/13.32 KiB
# ⠙ Preparing packages... (0/6)---------- 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/6)---------- 13.32 KiB/13.32 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/417.74 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/417.74 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/417.74 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/417.74 KiB
# protobuf             ------------------------------     0 B/417.74 KiB
# ⠙ Preparing packages... (0/6)-------------------     0 B/452.71 KiB
# protobuf             ------------------------------     0 B/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 14.88 KiB/452.71 KiB
# protobuf             ------------------------------ 16.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 14.88 KiB/452.71 KiB
# protobuf             ------------------------------ 16.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 30.88 KiB/452.71 KiB
# protobuf             ------------------------------ 32.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 30.88 KiB/452.71 KiB
# protobuf             ------------------------------ 32.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 46.88 KiB/452.71 KiB
# protobuf             ------------------------------ 48.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 46.88 KiB/452.71 KiB
# protobuf             ------------------------------ 48.00 KiB/417.74 KiB
# ⠙ Preparing packages... (0/6)------------------- 62.88 KiB/452.71 KiB
# protobuf             ------------------------------ 62.31 KiB/417.74 KiB
# pydantic             ------------------------------ 75.42 KiB/452.71 KiB
# pydantic-core        ------------------------------ 14.90 KiB/1.81 MiB
# ⠙ Preparing packages... (0/6)------------------- 16.00 KiB/22.21 MiB
# protobuf             ------------------------------ 238.10 KiB/417.74 KiB
# pydantic             ------------------------------ 251.42 KiB/452.71 KiB
# pydantic-core        ------------------------------ 158.73 KiB/1.81 MiB
# ⠙ Preparing packages... (0/6)------------------- 144.00 KiB/22.21 MiB
# protobuf             ------------------------------ 414.31 KiB/417.74 KiB
# pydantic-core        ------------------------------ 398.73 KiB/1.81 MiB
# ⠙ Preparing packages... (0/6)------------------- 256.00 KiB/22.21 MiB
# pydantic-core        ------------------------------ 494.73 KiB/1.81 MiB
# ⠙ Preparing packages... (0/6)------------------- 320.00 KiB/22.21 MiB
# pydantic-core        ------------------------------ 814.73 KiB/1.81 MiB
# ⠹ Preparing packages... (4/6)------------------- 848.00 KiB/22.21 MiB
# pydantic-core        ------------------------------ 1.64 MiB/1.81 MiB
# ⠹ Preparing packages... (4/6)------------------- 1.65 MiB/22.21 MiB
# ⠹ Preparing packages... (4/6)------------------- 3.34 MiB/22.21 MiB
# ⠹ Preparing packages... (4/6)------------------- 3.40 MiB/22.21 MiB
# ⠸ Preparing packages... (5/6)------------------- 4.25 MiB/22.21 MiB
# ⠸ Preparing packages... (5/6)------------------- 6.73 MiB/22.21 MiB
# ⠸ Preparing packages... (5/6)------------------- 7.62 MiB/22.21 MiB
# ⠸ Preparing packages... (5/6)2m----------------- 9.83 MiB/22.21 MiB
# ⠼ Preparing packages... (5/6)---------------- 10.95 MiB/22.21 MiB
# ⠼ Preparing packages... (5/6)30m------------ 13.33 MiB/22.21 MiB
# ⠼ Preparing packages... (5/6)----------- 14.39 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.27 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.54 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.55 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.56 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.58 MiB/22.21 MiB
# ⠴ Preparing packages... (5/6)---------- 15.59 MiB/22.21 MiB
# ⠦ Preparing packages... (5/6)---------- 16.83 MiB/22.21 MiB
# ⠦ Preparing packages... (5/6)---------- 17.05 MiB/22.21 MiB
# ⠦ Preparing packages... (5/6)---------- 18.54 MiB/22.21 MiB
# ⠦ Preparing packages... (5/6)---------- 19.56 MiB/22.21 MiB
# ⠧ Preparing packages... (5/6)---------- 20.28 MiB/22.21 MiB
# ⠧ Preparing packages... (5/6)---------- 20.81 MiB/22.21 MiB
# Prepared 6 packages in 1.33s
# Uninstalled 3 packages in 81ms
# Installed 6 packages in 16ms
#  + annotated-types==0.7.0
#  - protobuf==4.25.8
#  + protobuf==6.33.5
#  - pydantic==1.10.26
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + typing-inspection==0.4.2
#  - wandb==0.15.12
#  + wandb==0.25.0

# %%
# !uv pip install "pydantic<2.0"
# Out:
# Using Python 3.11.14 environment at: /Users/bingyiwang/VS Code/AI Project/.venv
# Resolved 2 packages in 3ms
# Uninstalled 1 package in 8ms
# Installed 1 package in 3ms
#  - pydantic==2.12.5
#  + pydantic==1.10.26

# %%
from huggingface_hub import login
from getpass import getpass
token = getpass("Enter your Hugging Face token: ")
login(token=token)

# %%
from datasets import load_dataset

ds = load_dataset("FreedomIntelligence/Medical_Multimodal_Evaluation_Data")

# %%
import os
output_folder = "Medical_Multimodal_Evaluation_Data"
filename = "medical_multimodel_evaluation_data.json"

os.makedirs(output_folder, exist_ok=True)
ds['test'].to_json(f"{output_folder}/{filename}")
# Out:
# Creating json from Arrow format: 100%|██████████| 18/18 [00:00<00:00, 235.05ba/s]
# 4556294

# %%
import requests
import zipfile
import os
from io import BytesIO

url = "https://huggingface.co/datasets/FreedomIntelligence/Medical_Multimodal_Evaluation_Data/resolve/main/images.zip"

print("Downloading images...")
response = requests.get(url)
target_folder = "Medical_Multimodal_Evaluation_Data/images"

if response.status_code == 200:
    print("Download complete. Unzipping...")
    os.makedirs(target_folder, exist_ok=True)
    with zipfile.ZipFile(BytesIO(response.content)) as z:
        z.extractall(target_folder)
    print(f"Images successfully unzipped to: {target_folder}")
else:
    print(f"Failed to download. Status code: {response.status_code}")
    print("Please check the exact URL on the Hugging Face dataset page.")
# Out:
# Downloading images...
# Download complete. Unzipping...
# Images successfully unzipped to: Medical_Multimodal_Evaluation_Data/images

# %%
# %cd ../HuatuoGPT-Vision-Replication
# !accelerate launch eval.py \
  --data_path Medical_Multimodal_Evaluation_Data/medical_multimodel_evaluation_data.json \
  --model_path FreedomIntelligence/HuatuoGPT-Vision-7B
# Out:
# /Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision-Replication
# [2026-03-04 11:34:21,006] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `0`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# [2026-03-04 11:34:26,114] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision-Replication
# Traceback (most recent call last):
#   File "/Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision-Replication/eval.py", line 179, in <module>
#     test(args)
#     ^^^^^^^^^^
#   File "/Users/bingyiwang/VS Code/AI Project/HuatuoGPT-Vision-Replication/eval.py", line 109, in test
#     torch.cuda.set_device(accelerator.process_index)
#   File "/Users/bingyiwang/VS Code/AI Project/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py", line 350, in set_device
#     torch._C._cuda_setDevice(device)
#     ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'torch._C' has no attribute '_cuda_setDevice'
# Traceback (most recent call last):
#   File "/Users/bingyiwang/VS Code/AI Project/.venv/bin/accelerate", line 12, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/bingyiwang/VS Code/AI Project/.venv/lib/python3.11/site-packages/accelerate/commands/accelerate_cli.py", line 45, in main
#     args.func(args)
#   File "/Users/bingyiwang/VS Code/AI Project/.venv/lib/python3.11/site-packages/accelerate/commands/launch.py", line 979, in launch_command
#     simple_launcher(args)
#   File "/Users/bingyiwang/VS Code/AI Project/.venv/lib/python3.11/site-packages/accelerate/commands/launch.py", line 628, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/Users/bingyiwang/VS Code/AI Project/.venv/bin/python3', 'eval.py', '--data_path', 'Medical_Multimodal_Evaluation_Data/medical_multimodel_evaluation_data.json', '--model_path', 'FreedomIntelligence/HuatuoGPT-Vision-7B']' returned non-zero exit status 1.
